# %%
import pandas as pd
import pyreadstat
import os
import numpy as np
from IPython.display import HTML, display
PATH = "/Users/renjiege/Documents/taskdata/Worldbank/"
dta = "PTA2_test.dta"
excel = "STRI_ScoreCard_1701.xlsx"

# %% [markdown]
# ### Import Data

# %%
table_names = ['ScoreCard_2016', 'ScoreAggregateByFunc_2016', 'ScoreAggregate_2016', 
               'ScoreNumeric_2016', 'ParentChildCode_2016','ParentChildCodeNumeric_2016']
pta = pd.read_stata(f'{PATH}{dta}')
pta['Measure_ID'] = pta.Measure_ID.astype(np.int64)

# %%
pta.Answer.value_counts()
# Out:
# yes    3028
# no      263
# 70       12
# 5        10
# 49        3
# Name: Answer, dtype: int64

# %%
tables = [pd.read_excel(f'{PATH}{excel}', sheet_name=f'{fname}') for fname in table_names]
score_card, aggregate_by_func, aggregate, numeric, parent_child, parent_child_numeric = tables

# %%
pd.options.display.max_colwidth = 80
pd.options.display.max_columns = 30
pd.options.display.max_rows = 100

# %%
score_card = score_card[["Code", "Answer", "Category", "Subcategory", "Subsector", "Score"]]
score_card[score_card.Code==149][["Code", "Answer", "Category", "Subcategory", "Subsector", "Score"]]
# Out:
#     Code Answer         Category Subcategory  \
# 26   149    yes  A -Market entry          A2
# 27   149    yes  A -Market entry          A2
#
#                                                               Subsector  Score
# 26  ;10874;10875;10891;10892;10873;10880;10882;10881;10883;152;174;169;  0.125
# 27              ;31;30;10904;207;206;136;10903;10901;10902;10897;10898;  0.250

# %% [markdown]
# ### Merging and Data cleaning

# %%
aggregate = aggregate.rename(columns={'Subsector ': 'Subsector'})

# %%
joined = pta.merge(score_card, left_on="Measure_ID", right_on="Code", how='outer', suffixes=('', '_s'))

# %%
joined['Sectorfine_ID'] = pta.Sectorfine_ID.astype(int).astype(str)

# %% [markdown]
# **Note**: Some measures have different scores for different sectors (Measure 25 for example). When we use the outer merge, these measures are mapped to wrong sectors. Thus we need to drop these measures where subsector information do not match.

# %%
dup_code = []
for t in joined.Code.unique():
    if len(joined[joined.Code==t]["Score"].unique())>1:
        dup_code.append(str(t))
dup_code
# Out:
# ['25', '149', '136', '39', '144']

# %%
joined['tag1'] = joined.apply(lambda x: str(x.Sectorfine_ID) in str(x.Subsector), axis=1)

# %%
joined['tag2'] = joined.apply(lambda x: str(x.Code) in dup_code, axis=1)

# %%
score_card[score_card.Code==25]
# Out:
#     Code Answer         Category Subcategory  \
# 81    25     no  A -Market entry          A1
# 82    25     no  A -Market entry          A1
#
#                                                                           Subsector  \
# 81  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 82                                                  ;10874;10875;10891;10892;10873;
#
#     Score
# 81   0.50
# 82   0.25

# %%
joined = joined[joined.Sectorfine_ID.isnull()==False]
joined[joined.Code==25][["Code", "Answer", "Category", "Sectorfine", "Sectorfine_ID", "M1", "M2", "M3","M4", "Subcategory", "Subsector", "Score", "tag1", "tag2"]]
# Out:
#       Code Answer         Category   Sectorfine Sectorfine_ID   M1   M2   M3  \
# 2591    25     no  A -Market entry    1.A.a.(b)         10873  0.0  0.0  1.0
# 2592    25     no  A -Market entry    1.A.a.(b)         10891  0.0  0.0  1.0
# 2593    25     no  A -Market entry  1.A.a.(a.1)         10892  0.0  0.0  1.0
# 2594    25     no  A -Market entry  1.A.a.(a.1)         10874  0.0  0.0  1.0
# 2595    25     no  A -Market entry  1.A.a.(a.2)         10874  0.0  0.0  1.0
# 2596    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2597    25     no  A -Market entry  1.A.a.(a.1)         10873  0.0  0.0  1.0
# 2598    25     no  A -Market entry  1.A.a.(a.1)         10873  0.0  0.0  1.0
# 2599    25     no  A -Market entry  1.A.a.(a.2)         10874  0.0  0.0  1.0
# 2600    25     no  A -Market entry  1.A.a.(a.2)         10874  0.0  0.0  1.0
# 2601    25     no  A -Market entry    1.A.a.(b)         10873  0.0  0.0  1.0
# 2602    25     no  A -Market entry    1.A.a.(b)         10875  0.0  0.0  1.0
# 2603    25     no  A -Market entry  1.A.a.(a.1)         10873  0.0  0.0  1.0
# 2604    25     no  A -Market entry  1.A.a.(a.1)         10875  0.0  0.0  1.0
# 2605    25     no  A -Market entry    1.A.a.(b)         10875  0.0  0.0  1.0
# 2606    25     no  A -Market entry    1.A.a.(b)         10874  0.0  0.0  1.0
# 2607    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2608    25     no  A -Market entry  1.A.a.(a.2)         10873  0.0  0.0  1.0
# 2609    25     no  A -Market entry  1.A.a.(a.1)         10891  0.0  0.0  1.0
# 2610    25     no  A -Market entry  1.A.a.(a.1)         10892  0.0  0.0  1.0
# 2611    25     no  A -Market entry    1.A.a.(b)         10875  0.0  0.0  1.0
# 2612    25     no  A -Market entry    1.A.a.(b)         10874  0.0  0.0  1.0
# 2613    25     no  A -Market entry  1.A.a.(a.2)         10874  0.0  0.0  1.0
# 2614    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2615    25     no  A -Market entry  1.A.a.(a.1)         10873  0.0  0.0  1.0
# 2616    25     no  A -Market entry  1.A.a.(a.1)         10874  0.0  0.0  1.0
# 2617    25     no  A -Market entry  1.A.a.(a.2)         10873  0.0  0.0  1.0
# 2618    25     no  A -Market entry  1.A.a.(a.2)         10873  0.0  0.0  1.0
# 2619    25     no  A -Market entry    1.A.a.(b)         10875  0.0  0.0  1.0
# 2620    25     no  A -Market entry    1.A.a.(b)         10874  0.0  0.0  1.0
# 2621    25     no  A -Market entry    1.A.a.(b)         10874  0.0  0.0  1.0
# 2622    25     no  A -Market entry    1.A.a.(b)         10874  0.0  0.0  1.0
# 2623    25     no  A -Market entry  1.A.a.(a.1)         10874  0.0  0.0  1.0
# 2624    25     no  A -Market entry  1.A.a.(a.1)         10874  0.0  0.0  1.0
# 2625    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2626    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2627    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2628    25     no  A -Market entry  1.A.a.(a.2)         10875  0.0  0.0  1.0
# 2629    25     no  A -Market entry    1.A.a.(b)         10875  0.0  0.0  1.0
# 2630    25     no  A -Market entry    1.A.a.(b)         10873  0.0  0.0  1.0
;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2614                                                  ;10874;10875;10891;10892;10873;
# 2615  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2616                                                  ;10874;10875;10891;10892;10873;
# 2617  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2618                                                  ;10874;10875;10891;10892;10873;
# 2619  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2620                                                  ;10874;10875;10891;10892;10873;
# 2621  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2622                                                  ;10874;10875;10891;10892;10873;
# 2623  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2624                                                  ;10874;10875;10891;10892;10873;
# 2625  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2626                                                  ;10874;10875;10891;10892;10873;
# 2627  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2628                                                  ;10874;10875;10891;10892;10873;
# 2629  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2630                                                  ;10874;10875;10891;10892;10873;
# 2631  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2632                                                  ;10874;10875;10891;10892;10873;
# 2633  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2634                                                  ;10874;10875;10891;10892;10873;
# 2635  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2636                                                  ;10874;10875;10891;10892;10873;
# 2637  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2638                                                  ;10874;10875;10891;10892;10873;
# 2639  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2640                                                  ;10874;10875;10891;10892;10873;
# 2641  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2642                                                  ;10874;10875;10891;10892;10873;
# 2643  ;31;30;10904;207;206;136;10901;10902;10903;10880;10882;10881;10883;10897;108...
# 2644                                                  ;10874;10875;10891;10892;10873;
#
#       Score   tag1  tag2
# 2591   0.50  False  True
# 2592   0.25   True  True
# 2593   0.50  False  True
# 2594   0.25   True  True
# 2595   0.50  False  True
# 2596   0.25   True  True
# 2597   0.50  False  True
# 2598   0.25   True  True
# 2599   0.50  False  True
# 2600   0.25   True  True
# 2601   0.50  False  True
# 2602   0.25   True  True
# 2603   0.50  False  True
# 2604   0.25   True  True
# 2605   0.50  False  True
# 2606   0.25   True  True
# 2607   0.50  False  True
# 2608   0.25   True  True
# 2609   0.50  False  True
# 2610   0.25   True  True
# 2611   0.50  False  True
# 2612   0.25   True  True
# 2613   0.50  False  True
# 2614   0.25   True  True
# 2615   0.50  False  True
# 2616   0.25   True  True
# 2617   0.50  False  True
# 2618   0.25   True  True
# 2619   0.50  False  True
# 2620   0.25   True  True
# 2621   0.50  False  True
# 2622   0.25   True  True
# 2623   0.50  False  True
# 2624   0.25   True  True
# 2625   0.50  False  True
# 2626   0.25   True  True
# 2627   0.50  False  True
# 2628   0.25   True  True
# 2629   0.50  False  True
# 2630   0.25   True  True
# 2631   0.50  False  True
# 2632   0.25   True  True
# 2633   0.50  False  True
# 2634   0.25   True  True
# 2635   0.50  False  True
# 2636   0.25   True  True
# 2637   0.50  False  True
# 2638   0.25   True  True
# 2639   0.50  False  True
# 2640   0.25   True  True
# 2641   0.50  False  True
# 2642   0.25   True  True
# 2643   0.50  False  True
# 2644   0.25   True  True

# %%
joined = joined.drop(joined[(joined.tag1==False) & (joined.tag2==True)].index)

# %%
joined = joined.drop(['tag1', 'tag2', 'Subsector'], axis=1)

# %%
joined.Answer_s.value_counts()
# Out:
# yes        2804
# no          186
# numeric      14
# Name: Answer_s, dtype: int64

# %%
# parent_child[parent_child.columns.drop(list(parent_child.filter(regex='Unnamed')))]

# %% [markdown]
# The scorecard has some three main functions that modify the scores under certain conditions.

# %% [markdown]
# ### Parent-child function

# %% [markdown]
# First define a function that finds parent code index given the child index, then use this function to locate the parent answer and compare it with the answer in the parent_child spreadsheet. Generate a dummy to indicate whether the child measure is active.

# %%
def parent(key):
    Dict = {x: y for x,y in zip(parent_child.ChildCode, parent_child.ParentCode)}
    return Dict[key]

def default(key):
    Dict = {x: y for x,y in zip(parent_child.ChildCode, parent_child.ParentAnswer)}
    return Dict[key]

# %%
def find_parent_index(child_index):
    child_code = joined.loc[(child_index), ['Code']].values[0]
    parent_code = parent(child_code)
    sector_id = str(joined.loc[(child_index), ['Sectorfine_ID']].values[0])
    regime = joined.loc[(child_index), ['regime_id']].values[0]
    parent_index = joined[(joined.Sectorfine_ID==sector_id) & (joined.regime_id==regime) & (joined.Code==parent_code)].index
#     print(parent_code)
#     print(sector_id)
#     print(regime)
    return parent_index

# %%
joined['active']=1
for index, row in joined.iterrows():
    each = row['Code']
    child_index = index
    if each in list(parent_child.ChildCode):
        default_answer = default(each)    
#         print(each)
        parent_index = find_parent_index(child_index)
#         print(parent_index)
        if parent_index.values.any()==True:  # i.e., if parent code exists
            parent_answer = joined.loc[(parent_index), ['Answer']].values[0]
            if parent_answer!=default_answer:
                joined.loc[joined.Code==each,'active']=0

# %% [markdown]
# ### Numeric function

# %% [markdown]
# First define a function that returns score given the numeric answer and associated measure code, subsector, and mode. Then apply this function to each row in the joined dataframe.

# %%
def get_numeric_score(code, answer, subsector):
    for idx, row in numeric.iterrows():
        Max = int(row['Max'])
        Min = int(row['Min'])
        Code = row['Code']
        Subsector = row['Subsector_numeric']
#         Mode = row['Mode']
        if answer<=Max and answer>=Min and code==Code and (str(subsector) in Subsector):
                score = numeric.loc[(idx), 'Score']
                return score

# %%
get_numeric_score(27, 26, 206)
# Out:
# 0.25

# %%
joined['Score_s'] = joined.Score
joined.loc[joined.Answer_s!=joined.Answer, "Score_s"] =0

# %%
for idx, row in joined.iterrows():
    if row['Answer_s'] == 'numeric':
#         print(idx)
        answer = int(row['Answer'])
        code = row['Code']
        subsector= row['Sectorfine_ID']
        Score = get_numeric_score(code, answer, subsector)
        joined.loc[(idx), 'Score_s'] = Score

# %%
# joined.loc[((joined.Code==137) | (joined.Code==139))]

# %% [markdown]
# ### Aggregation function

# %% [markdown]
# There are three main steps involved aggregating subcode into a pseudo code. First, define a function "get_pseudo_score", which outputs the pseudo code and its corresponding score given data. Then define a function, "get_pseudo_data", which given dataframe, produces the data that need to be added to the dataframe. Lastly, we update the df by group at regime-country-sector level.
#
#
# The following test sample is a good subsample to examine the performance of the code. It contains two sets of codes that need to be aggregated into one pseudo code.

# %%
test = joined.loc[(joined.Regime=="ASEAN - Korea, Republic of") & (joined.Country=="Brunei Darussalam") & (joined.Sectorfine_ID=="10873")] \
    [['Regime', 'Country', 'Sectorfine_ID', 'Subcategory', 'Answer', 'Code', 'Score', 'Score_s', 'M1', 'M2', 'M3', 'M4']]
df = joined[['Regime', 'Country', 'Sectorfine_ID', 'Subcategory', 'Answer', 'Code', 'Score', 'Score_s', 'M1', 'M2', 'M3', 'M4']].reset_index(drop=True)
df = df.drop(df[df.Country==""].index)

# %%
def get_pseudo_score(data):
    dic, subcategory, subsector, mode = data
    for idx, row in aggregate.iterrows():
        sub = row['Subsector']
        code = row['Code']
        answer = row['Answer']
        Pseudo_code = None
        score = None
        if (subcategory==row['Subcategory']) and (subsector in sub) and (row['Mode'] in mode):
            if answer=='no':
                list_code = [y for x,y in zip(dic.values(), dic.keys()) if x =='no']
                concat_code = ','.join(sorted(list_code, key=float))
                if concat_code == code:
                    Pseudo_code = aggregate.loc[(idx), 'PseudoCode']
                    score = aggregate.loc[(idx), 'Score']
                    return Pseudo_code, score
            else:
                list_code = [y for x,y in zip(dic.values(), dic.keys()) if x =='yes']
                concat_code = ','.join(sorted(list_code, key=float))
                if concat_code == code:
                    Pseudo_code = aggregate.loc[(idx), 'PseudoCode']
                    score = aggregate.loc[(idx), 'Score']
                    return Pseudo_code, score

# %%
dic = {'137': 'no', '139': 'no'}
get_pseudo_score([dic, 'A1', '10904', ['M1','','M3','M4']])
# Out:
# ('9991C', 0.5)

# %%
list_single = [x for x in list(aggregate.Code.unique()) if (',' not in x)]
list_multiple = [list_single[n:n+3] for n in range(0, len(list_single), 3)]

# %%
def get_related_codes(x):
    for y in list_multiple:
        if str(x) in y:
            other_code = [s for s in y if s != str(x)]
            return other_code

# %%
get_related_codes(137)
# Out:
# ['136', '139']

# %%
def get_pseudo_data(df): 
    
    code_to_answer = {str(s): str(t) for s,t in zip(df.Code, df.Answer)}
    unique_code = list(df.Code.unique().astype(str))
    
    pseudo_data_list = []
    for idx, row in df.iterrows():
        
        subsector = row['Sectorfine_ID']
        subcategory = row['Subcategory']
        M1 = int(row['M1'])*'M1'
        M2 = int(row['M2'])*'M2'
        M3 = int(row['M3'])*'M3'
        M4 = int(row['M4'])*'M4'
        mode = [M1, M2, M3, M4]
    
        if str(row['Code']) in list_single:
            answer_1 = row['Answer']
            related_codes = get_related_codes(row['Code'])
            all_codes = [str(row['Code'])] + related_codes
            answer={str(row['Code']): answer_1}
            
            for i, j in enumerate(related_codes):
                if j in unique_code: 
                    other_answer = {j: code_to_answer[j]}
                    answer.update(other_answer)
            
            data = [answer, subcategory, subsector, mode] 
            pseudo_code, score = get_pseudo_score(data)
            pseudo_data = (pseudo_code, score, subcategory, ','.join(list(answer.values())), subsector, M1, M2, M3, M4)
            pseudo_data_list.append(pseudo_data) 
     
    return list(set(pseudo_data_list))

# %%
get_pseudo_data(test)
# Out:
# [('9991Ab', 0.125, 'A2', 'yes', '10873', '', '', '', 'M4')]

# %%
def add_pseudo_data(df):
    pseudo_data = get_pseudo_data(df)
    if pseudo_data:
        for each in pseudo_data:
            last_row = df.iloc[[-1]]
            data_list = list(each)
            last_row['Subcategory'] = data_list[2]
            last_row['Score_s'] = data_list[1]
            last_row['Code'] = data_list[0]
            last_row['M1'] = 1 if data_list[-4] else 0
            last_row['M2'] = 1 if data_list[-3] else 0
            last_row['M3'] = 1 if data_list[-2] else 0
            last_row['M4'] = 1 if data_list[-1] else 0
            df = df.append(last_row)
        return df
    return df

# %%
# add_pseudo_data(test)

# %%
df = df.groupby(['Regime', 'Country','Sectorfine_ID']).apply(add_pseudo_data).reset_index(drop=True)

# %%
for each in list_single:
    df = df.drop(df[df.Code==int(each)].index)

# %%
df.Code.unique()
# Out:
# array([12, 19, 15, 82, 227, 24, 38, 827, 25, 40, 54, 62, '9991Ab',
#        '9991A', 66, 300, 13, 89, 75, 860], dtype=object)

# %%
df = df.drop(['Score'], axis=1)

# 3264             US - Singapore  United States of America         10873
# 3265             US - Singapore  United States of America         10873
# 3266             US - Singapore  United States of America         10873
# 3267             US - Singapore  United States of America         10873
# 3268             US - Singapore  United States of America         10873
# 3269             US - Singapore  United States of America         10874
# 3270             US - Singapore  United States of America         10874
# 3271             US - Singapore  United States of America         10875
# 3272             US - Singapore  United States of America         10875
# 3273             US - Singapore  United States of America         10875
# 3274             US - Singapore  United States of America         10891
# 3275               Ukraine - EU                   Ukraine         10873
# 3276               Ukraine - EU                   Ukraine         10873
# 3277               Ukraine - EU                   Ukraine         10874
# 3278               Ukraine - EU                   Ukraine         10875
# 3279               Ukraine - EU                   Ukraine         10875
# 3280               Ukraine - EU                   Ukraine         10891
# 3281               Ukraine - EU                   Ukraine         10891
# 3282               Ukraine - EU                   Ukraine         10892
# 3283               Ukraine - EU                   Ukraine         10892
# 3284               Ukraine - EU                   Ukraine         10892
# 3285       Ukraine - Montenegro                   Ukraine         10873
# 3286       Ukraine - Montenegro                   Ukraine         10875
# 3287       Ukraine - Montenegro                   Ukraine         10875
# 3288       Ukraine - Montenegro                   Ukraine         10892
#
#      Subcategory Answer Code  Score_s   M1   M2   M3   M4
# 0             A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 1             A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 2             A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 3             A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 4             A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 5             A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 6             A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 7             A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 8             A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 9             A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 10            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 11            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 12            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 13            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 14            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 15            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 16            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 17            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 18            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 19            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 20            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 21            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 22            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 23            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 24            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 25            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 26            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 27            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 28            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 29            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 30            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 31            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 32            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 33            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 34            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 35            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 36            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 37            B1    yes   15     0.25  0.0  0.0  1.0  0.0
# 38            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 39            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 40            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 41            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 42            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 43            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 44            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 45            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 46            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 47            A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 48            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 49            A1    yes   19     1.00  0.0  0.0  1.0  0.0
# ...          ...    ...  ...      ...  ...  ...  ...  ...
# 3239          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3240          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3241          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3242          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3243          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3244          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3245          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3246          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3247          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3248          A4    yes  827     0.25  0.0  0.0  1.0  0.0
# 3249          A4    yes  827     0.25  0.0  0.0  1.0  0.0
# 3250          A4    yes  827     0.25  0.0  0.0  1.0  0.0
# 3251          A4    yes  827     0.25  0.0  0.0  1.0  0.0
# 3252          A4    yes  827     0.25  0.0  0.0  1.0  0.0
# 3253          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3254          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3255          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3256          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3257          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3258          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3259          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3260          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3261          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3262          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3263          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3264          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3265          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3266          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3267          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3268          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3269          E1    yes  860     0.00  0.0  0.0  0.0  1.0
# 3270          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3271          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3272          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3273          A1    yes   13     0.75  1.0  0.0  0.0  0.0
# 3274          E1    yes  860     0.00  0.0  0.0  1.0  0.0
# 3275          A3    yes   89     0.75  0.0  0.0  1.0  0.0
# 3276          A3    yes   89     0.75  1.0  0.0  0.0  0.0
# 3277          A3    yes   89     0.75  1.0  0.0  0.0  0.0
# 3278          A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 3279          A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 3280          A3    yes   89     0.75  1.0  0.0  0.0  0.0
# 3281          A3    yes   89     0.75  0.0  0.0  1.0  0.0
# 3282          A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 3283          A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 3284          A3    yes   89     0.75  0.0  0.0  1.0  0.0
# 3285          A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 3286          A1    yes   19     1.00  0.0  0.0  1.0  0.0
# 3287          A1    yes   12     1.00  1.0  0.0  0.0  0.0
# 3288          A1    yes   12     1.00  1.0  0.0  0.0  0.0
#
# [3168 rows x 11 columns]

# %%
df[df.Code==24]
# Out:
#                                           Regime     Country Sectorfine_ID  \
# 124              ASEAN - Australia - New Zealand   Indonesia         10873
# 131              ASEAN - Australia - New Zealand   Indonesia         10874
# 138              ASEAN - Australia - New Zealand   Indonesia         10875
# 957                            Costa Rica - Peru  Costa Rica         10873
# 961                            Costa Rica - Peru  Costa Rica         10874
# 962                            Costa Rica - Peru  Costa Rica         10874
# 963                            Costa Rica - Peru  Costa Rica         10874
# 964                            Costa Rica - Peru  Costa Rica         10875
# 1796  Gulf Cooperation Council (GCC) - Singapore        Oman         10874
# 1797  Gulf Cooperation Council (GCC) - Singapore        Oman         10875
# 1798  Gulf Cooperation Council (GCC) - Singapore        Oman         10875
# 3219                                   US - Oman        Oman         10873
# 3220                                   US - Oman        Oman         10873
# 3225                                   US - Oman        Oman         10875
#
#      Subcategory Answer Code  Score_s   M1   M2   M3   M4
# 124           A1     49   24   0.1250  0.0  0.0  1.0  0.0
# 131           A1     49   24   0.1250  0.0  0.0  1.0  0.0
1    yes   12   1.0000  1.0  0.0  0.0  0.0
# ...          ...    ...  ...      ...  ...  ...  ...  ...
# 3211          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3212          A1    yes   13   0.7500  1.0  0.0  0.0  1.0
# 3214          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3217          A1    yes   13   0.7500  1.0  0.0  0.0  1.0
# 3218          A4    yes  827   0.2500  0.0  0.0  1.0  1.0
# 3219          A1     70   24   0.0625  0.0  0.0  1.0  0.0
# 3221          A4    yes  827   0.2500  0.0  0.0  1.0  1.0
# 3224          A4    yes  827   0.2500  0.0  0.0  1.0  1.0
# 3225          A1     70   24   0.0625  0.0  0.0  1.0  0.0
# 3226          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3227          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3229          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3232          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3234          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3236          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3237          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3238          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3239          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3240          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3243          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3245          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3247          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3248          A4    yes  827   0.2500  0.0  0.0  1.0  0.0
# 3251          A4    yes  827   0.2500  0.0  0.0  1.0  0.0
# 3253          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3254          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3256          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3258          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3261          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3262          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3264          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3266          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3268          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3269          E1    yes  860   0.0000  0.0  0.0  0.0  1.0
# 3270          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3271          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3272          A1    yes   13   0.7500  1.0  0.0  0.0  0.0
# 3274          E1    yes  860   0.0000  0.0  0.0  1.0  0.0
# 3275          A3    yes   89   0.7500  0.0  0.0  1.0  0.0
# 3276          A3    yes   89   0.7500  1.0  0.0  0.0  0.0
# 3277          A3    yes   89   0.7500  1.0  0.0  0.0  0.0
# 3278          A1    yes   19   1.0000  0.0  0.0  1.0  0.0
# 3280          A3    yes   89   0.7500  1.0  0.0  0.0  0.0
# 3281          A3    yes   89   0.7500  0.0  0.0  1.0  0.0
# 3282          A1    yes   12   1.0000  1.0  0.0  0.0  0.0
# 3284          A3    yes   89   0.7500  0.0  0.0  1.0  0.0
# 3285          A1    yes   19   1.0000  0.0  0.0  1.0  0.0
# 3286          A1    yes   19   1.0000  0.0  0.0  1.0  0.0
# 3287          A1    yes   12   1.0000  1.0  0.0  0.0  0.0
# 3288          A1    yes   12   1.0000  1.0  0.0  0.0  0.0
#
# [1814 rows x 11 columns]

# %%
df.to_csv('PTA2_test_rd_02192019.csv', sep=',')
